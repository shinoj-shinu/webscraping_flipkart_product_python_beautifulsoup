# %%
#web_scraping_flipcart.com_python_beauiful_soup

# %%
##libraries-beautiful soup,requests,csv,pandas

# %%
#import libraries

# %%
import bs4

# %%
import requests

# %%
import csv

# %%
import pandas as pd

# %%
result = requests.get("https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&as-pos=1&as-type=RECENT&suggestionId=laptop%7CLaptops&requestId=7ec220e8-4f02-4150-9e0b-9e90cf692f4b&as-searchtext=laptop")

# %%
type(result)
# Out:
# requests.models.Response

# %%
result.text
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.6e7580.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/ap
# ...

# %%
import bs4

# %%
soup = bs4.BeautifulSoup(result.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.select("tittle")
# Out:
# []

# %%
soup.select("p")
# Out:
# [<p class="_2-N8zT">Wonderful</p>,
#  <p class="_2sc7ZR _2V5EHH">Vinod Tarsariya</p>,
#  <p class="_2mcZGG" id="review-e4d91632-0060-42ea-b4f5-1c31efb216ee"><span>Certified Buyer</span></p>,
#  <p class="_2sc7ZR">8months ago</p>,
#  <p class="_2-N8zT">Great product</p>,
#  <p class="_2sc7ZR _2V5EHH">Vinay .S</p>,
#  <p class="_2mcZGG" id="review-412f9859-5c0c-48b5-9741-a75f77b536ee"><span>Certified Buyer</span></p>,
#  <p class="_2sc7ZR">1day ago</p>,
#  <p class="_2-N8zT">BEST OPTION UNDER 45000.</p>,
#  <p class="_2sc7ZR _2V5EHH">Gourab Chakraborty</p>,
#  <p class="_2mcZGG" id="review-0283bb07-67de-465e-8fd0-724e354c3421"><span>Certified Buyer</span></p>,
#  <p class="_2sc7ZR">Apr, 2021</p>,
#  <p class="_2-N8zT">Moderate</p>,
#  <p class="_2sc7ZR _2V5EHH">Mr. Sid Gupta</p>,
#  <p class="_2mcZGG" id="review-9b0be82c-cd5b-4d8a-98c2-539b5679c366"><span>Certified Buyer</span></p>,
#  <p class="_2sc7ZR">1day ago</p>,
#  <p class="_2-N8zT">Simply awesome</p>,
# ...

# %%
## need to extract laptop name,price and ratings

# %%
product=[]
prices=[]
ratings=[]
product=soup.find('div',attrs={"class":"_4rR01T"})

# %%
product.text
# Out:
# 'Lenovo IdeaPad Gaming 3 Core i5 11th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeFor...'

# %%
prices=soup.find('div',attrs={"class":"_30jeq3 _1_WHN1"})

# %%
prices.text
# Out:
# '₹59,990'
